# %% [markdown]
# # Applying Transformers and Explainable AI to Identify Partisan Keywords

# %% [markdown]
# *Best viewed as a colab notebook since visual text explorer features are not visible in the .ipynb file*: https://colab.research.google.com/drive/1mOSWKcD7pKSFSdyq2FBWTrhZ06SLTnLC?usp=sharing or via nbviewer: https://nbviewer.jupyter.org/github/AschHarwood/text_explorer/blob/main/analysis/notebooks/BERT_Explain%20%281%29.ipynb
#
# The following notebook uses a fine-tuned BERT transformer model to predict the partisan lean of the publisher of a news article. To create this supervised model, I used ktrain, a wrapper for Hugging Face's implementation of the BERT transformer, fine-tuned on the political news dataset used throughout this repository. I then trained the model to classify each article based on the partisan-bias labels in the dataset. The notebook for the fine-tuning and model training can be found [here](https://nbviewer.jupyter.org/github/AschHarwood/text_explorer/blob/main/analysis/notebooks/ktrain.ipynb).
#
# The model is highly accurate, with 93 percent accuracy, and respectable f1-scores, ranging from 0.91 to 0.93. Notably, the dataset is somewhat imbalanced, with the number of center-leaning articles roughly equivalent to right and left articles combined.
#
# However, the point of this model is not necessarily to predict the bias lean of an article (although there might be applications for validating message development), but to derive insights from model to understand what keywords are driving the model results.
#
# To generate these insights, I used ktrain's `predict.explain()` method, which is a wrapper for ELI5 package, a python implementation of LIME for explainable AI. By passing article text to ktrain's `explain`, we can visually explore the keywords that contributed toward and detracted from the model's prediction.
#
# I created five examples for each partisan lean below. Green highlighted words contribute to the prediction and red detract from it. The `score` metric is the "accuracy score weighted by cosine distance between generated sample and the original document." The higher the score, the better. LIME works by generating slightly altered synthetic samples of the original text, and training a "white box" classifier to determine the most important words.
#
# The `contribution` metric is similar to r-squared. It gives us a sense of how important the top words are to the predictive model. Once again, higher is better.
#
# ## General Findings
#
# While in theory, this is a potentially powerful tool to extract useful keywords, it also highlights the shortcomings of keywords extraction techniques generally.
#
# - Unigrams are not great for extracting meaningful insights. But, building this particular model was by the far the most compute intensive task in this repository and using bi and/or trigrams would require significantly more computing power (and patience) to train the model.
#
# - The meaningfulness of keywords needs to be interpreted using the contribution metric. Higher means the highlighted keywords are more important for the model's prediction. Lower contribution metrics reduce the usefulness of the keywords that are highlighted.
#
# - Outputs are particularly useful for identifying problems with the text, in this case data leakage. For example, for center leaning predictions, `reuters` is the most important keyword. Since `reuters` is considered a `center` news source, this essentially means that the model is getting a peak at the label while it is training.
#
# - The `explain` method does not return general findings or patterns about each label class but explanations for individual samples. This means they might not generalize to the entire corpus.
#
# ## Implications for Media Makers and Advocates
#
# - This approach allows us to leverage black box classification models to gain insights into the language associated with a particular audience. However, to be meaningful, additional preprocessing is needed, such as more thorough text cleaning, creation of bigrams and trigrams, etc.

# %% [markdown]
# # Imports and Installs

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#!pip install git+https://github.com/amaiya/eli5@tfkeras_0_10_1

# %%
#!pip install ktrain

# %%
import numpy as np
import ktrain
from ktrain import text
import urllib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Loading Ktrain Model

# %%
urllib.request.urlretrieve('https://nyc3.digitaloceanspaces.com/politicalnews//home/jupyter/text_explorer/analysis/predictor_news_sources_ktrain_model/config.json?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=KSJCKUT5V42U4OBV57JG%2F20210327%2Fnyc3%2Fs3%2Faws4_request&X-Amz-Date=20210327T153232Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=4ec8871801abbdabd9b19d4af1568a5d11595c48d6dd7d4c35919571000f990fc', '/content/drive/MyDrive/Colab Notebooks/text_model/config.json')
# Out:
# ('/content/drive/MyDrive/Colab Notebooks/text_model/config.json',
#  <http.client.HTTPMessage at 0x7fba011f3d90>)

# %%
urllib.request.urlretrieve('https://nyc3.digitaloceanspaces.com/politicalnews//home/jupyter/text_explorer/analysis/predictor_news_sources_ktrain_model/tf_model.h5?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=KSJCKUT5V42U4OBV57JG%2F20210327%2Fnyc3%2Fs3%2Faws4_request&X-Amz-Date=20210327T153458Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=fc2d854c208f815644cc5f675a25d98129a3c8f8cf1324b3ede24bb36568cc72', '/content/drive/MyDrive/Colab Notebooks/text_model/tf_model.h5')
# Out:
# ('/content/drive/MyDrive/Colab Notebooks/text_model/tf_model.h5',
#  <http.client.HTTPMessage at 0x7fba011f3f90>)

# %%
urllib.request.urlretrieve('https://nyc3.digitaloceanspaces.com/politicalnews//home/jupyter/text_explorer/analysis/predictor_news_sources_ktrain_model/tf_model.preproc?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=KSJCKUT5V42U4OBV57JG%2F20210327%2Fnyc3%2Fs3%2Faws4_request&X-Amz-Date=20210327T153554Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=5b76b02786c6fa1c88619166976997e8912df36a8cb7aa0abbc8cca5833568f1', '/content/drive/MyDrive/Colab Notebooks/text_model/tf_model.preproc')
# Out:
# ('/content/drive/MyDrive/Colab Notebooks/text_model/tf_model.preproc',
#  <http.client.HTTPMessage at 0x7fba01200690>)

# %%
#loads ktrain model
aareloaded_predictor = ktrain.load_predictor('/content/drive/MyDrive/Colab Notebooks/text_model')

# %% [markdown]
# # Loading Dataset

# %%
import pandas as pd

pd.set_option('display.max_columns', 500)

df = pd.read_csv('https://nyc3.digitaloceanspaces.com/politicalnews/domain_stop_removed_bias_text.csv')

df.head()

text_label = df[['text_stop_removed', 'audience_combined_bias']]

def replace_str(x):
    if x == 'left':
        return 0
    elif x == 'center':
        return 1
    else:
        return 2

text_label['label'] = text_label['audience_combined_bias'].apply(lambda x: replace_str(x))

text_label = text_label[['text_stop_removed', 'audience_combined_bias']]

text_label.columns = ['text', 'label']

text_label['text'] = text_label['text'].astype('string')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
text_label.head()
# Out:
#                                                 text   label
# 0  story update department health human service h...    left
# 1  story produce originally publish grist reprodu...    left
# 2  cúcuta colombia close military intervention ve...    left
# 3  glisten tiara royal purple line sash burroughs...    left
# 4  washington reuters democrat house representati...  center

# %% [markdown]
# #Left Example

# %%
left = text_label[text_label['label']=='left']

# %%
left = left.sample(5)
left
# Out:
#                                                      text label
# 122147  washington cnn blame iran tuesday shoot mq-9 d...  left
# 126242  month invasion france dozen b-24 american bomb...  left
# 97885   press gop   trump disavow send page july 19 pr...  left
# 44844   feel month medium infatuated piece flashy tech...  left
# 55800   acorn fat california hazelnut trail center tab...  left

# %%
#helper function for ktrain.explain
def get_doc(df, ix, filter):
  new_df = df[df['label']==filter]
  label = new_df['label'].iloc[ix]
  text = new_df['text'].iloc[ix]
  return text, label

# %%
text, label = get_doc(text_label, 0, 'left')
print(label)
aareloaded_predictor.explain(text)
# Out:
# left
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=left
#
# </b>
#
#
#     (probability <b>0.976</b>, score <b>6.883</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.754
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.129
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 93.07%); opacity: 0.82" title="0.224">story</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.73%); opacity: 0.84" title="-0.507">update</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.40%); opacity: 0.82" title="0.209">department</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.02%); opacity: 0.81" title="0.102">health</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.56%); opacity: 0.81" title="0.082">human</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.12%); opacity: 0.80" title="-0.035">service</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.38%); opacity: 0.82" title="0.210">hh</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.87%); opacity: 0.82" title="0.281">washington</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.28%); opacity: 0.82" title="0.214">thousand</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.03%); opacity: 0.80" title="-0.067">migrant</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.93%); opacity: 0.80" title="0.040">child</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.14%); opacity: 0.81" title="0.135">allegedly</span><span style="opacity: 0.80"> suffer </span><span style="background-color: hsl(0, 100.00%, 97.52%); opacity: 0.80" title="-0.051">sexual</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.40%); opacity: 0.81" title="-0.125">abuse</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.11%); opacity: 0.81" title="-0.178">government</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.45%); opacity: 0.80" title="-0.054">custody</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.95%); opacity: 0.80" title="0.039">past</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.92%); opacity: 0.81" title="-0.070">accord</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.43%); opacity: 0.83" title="0.356">department</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.02%); opacity: 0.81" title="0.102">health</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.56%); opacity: 0.81" title="0.082">human</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.12%); opacity: 0.80" title="-0.035">service</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.23%); opacity: 0.81" title="-0.172">hh</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.59%); opacity: 0.81" title="-0.201">document</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.88%); opacity: 0.81" title="-0.107">release</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.62%); opacity: 0.80" title="-0.049">tuesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.06%); opacity: 0.82" title="-0.322">florida</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.13%); opacity: 0.81" title="-0.098">democratic</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.15%); opacity: 0.83" title="-0.370">rep</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100 ...

# %%
text, label = get_doc(text_label, 1, 'left')
print(label)
aareloaded_predictor.explain(text)
# Out:
# left
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=left
#
# </b>
#
#
#     (probability <b>0.997</b>, score <b>5.151</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.797
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.354
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="2.238">story</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 70.36%); opacity: 0.93" title="1.459">produce</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.13%); opacity: 0.86" title="0.652">originally</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 74.60%); opacity: 0.90" title="1.170">publish</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.46%); opacity: 0.87" title="0.804">grist</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.68%); opacity: 0.81" title="-0.125">reproduce</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.86%); opacity: 0.81" title="0.059">climate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.18%); opacity: 0.80" title="-0.027">desk</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 76.31%); opacity: 0.89" title="1.059">collaboration</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.81%); opacity: 0.80" title="-0.035">october</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.79%); opacity: 0.81" title="-0.122">land</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.67%); opacity: 0.83" title="0.324">thirsty</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.56%); opacity: 0.80" title="0.041">shasta</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.99%); opacity: 0.80" title="-0.012">big</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.60%); opacity: 0.81" title="-0.096">spring</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.07%); opacity: 0.80" title="-0.030">ranch</span><span style="opacity: 0.80"> nestle hillside stud </span><span style="background-color: hsl(0, 100.00%, 89.74%); opacity: 0.83" title="-0.320">scrubby</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.90%); opacity: 0.83" title="-0.313">stunt</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.48%); opacity: 0.81" title="-0.168">juniper</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.23%); opacity: 0.83" title="-0.299">tree</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.40%); opacity: 0.81" title="0.135">snow</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.56%); opacity: 0.81" title="0.067">cap</span><span style="opacity: 0.80"> mount </span><span style="background-color: hsl(0, 100.00%, 93.54%); opacity: 0.81" title="-0.165">shasta</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.54%); opacity: 0.81" title="-0.165">tower</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.72%); opacity: 0.83" title="-0.321">dominate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.15%); opacity: 0.85" title="-0.543">skyline</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.64%); opacity: 0.83" title="-0.325">nearly</span><span style="opacity: 0.80"> northern </span><span style="background-color: hsl(0, 100.00%, 99.52%); opacity: 0.80" title="-0.004">california</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 86.21%); opacity: 0.84" title="-0.489">siskiyou</span><span style="opacity: 0.80"> </span><span style="backgr ...

# %%
text, label = get_doc(text_label, 2, 'left')
print(label)
aareloaded_predictor.explain(text)
# Out:
# left
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=left
#
# </b>
#
#
#     (probability <b>0.992</b>, score <b>4.090</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.988
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.102
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 91.92%); opacity: 0.82" title="0.646">cúcuta</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.00%); opacity: 0.81" title="0.237">colombia</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.15%); opacity: 0.82" title="0.510">close</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.83%); opacity: 0.81" title="0.251">military</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.71%); opacity: 0.80" title="-0.047">intervention</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.39%); opacity: 0.81" title="-0.204">venezuela</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.64%); opacity: 0.80" title="-0.051">weekend</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.30%); opacity: 0.80" title="-0.020">back</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.65%); opacity: 0.80" title="-0.110">venezuelan</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.67%); opacity: 0.80" title="0.007">opposition</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.17%); opacity: 0.81" title="-0.223">clash</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.59%); opacity: 0.81" title="-0.189">president</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.73%); opacity: 0.81" title="0.177">nicolás</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.45%); opacity: 0.80" title="0.061">maduro</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.65%); opacity: 0.81" title="-0.359">force</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.83%); opacity: 0.82" title="-0.656">swelter</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.21%); opacity: 0.80" title="-0.023">cúcuta</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.62%); opacity: 0.80" title="-0.052">colombian</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.05%); opacity: 0.80" title="0.153">border</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.85%); opacity: 0.80" title="0.002">venezuelan</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.93%); opacity: 0.80" title="0.036">opposition</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.93%); opacity: 0.80" title="0.036">dispatch</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.25%); opacity: 0.81" title="-0.215">convoy</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.05%); opacity: 0.81" title="-0.232">truck</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.31%); opacity: 0.81" title="-0.391">fill</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.64%); opacity: 0.81" title="-0.359">humanitarian</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.74%); opacity: 0.80" title="-0.005">aid</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.18%); opacity: 0.80" title="0.144">numerous</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.16%); opacity: 0.80" title="-0.145">border</span><span style="opacity: 0.80"> </span><span style="background-colo ...

# %%
text, label = get_doc(text_label, 3, 'left')
print(label)
aareloaded_predictor.explain(text)
# Out:
# left
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=left
#
# </b>
#
#
#     (probability <b>0.987</b>, score <b>3.870</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.599
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.272
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 95.82%); opacity: 0.81" title="0.168">glisten</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.43%); opacity: 0.81" title="-0.134">tiara</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.20%); opacity: 0.80" title="-0.095">royal</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.29%); opacity: 0.80" title="-0.047">purple</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.17%); opacity: 0.80" title="0.052">line</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.75%); opacity: 0.82" title="-0.370">sash</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.45%); opacity: 0.81" title="-0.133">burroughs</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.25%); opacity: 0.80" title="0.093">high</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.35%); opacity: 0.80" title="-0.088">school</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.61%); opacity: 0.81" title="-0.309">senior</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.58%); opacity: 0.81" title="-0.182">kate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.89%); opacity: 0.80" title="-0.025">platten</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.31%); opacity: 0.81" title="0.261">relish</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.11%); opacity: 0.81" title="-0.275">newly</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.66%); opacity: 0.83" title="-0.530">earn</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.19%); opacity: 0.81" title="-0.206">title</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.97%); opacity: 0.81" title="-0.159">role</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.50%); opacity: 0.81" title="0.131">royal</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.16%); opacity: 0.80" title="-0.052">international</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.25%); opacity: 0.80" title="0.014">miss</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.34%); opacity: 0.81" title="-0.196">teen</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.42%); opacity: 0.81" title="-0.254">california</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.81%); opacity: 0.80" title="0.067">17</span><span style="opacity: 0.80">-</span><span style="background-color: hsl(0, 100.00%, 98.06%); opacity: 0.80" title="-0.056">year</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.03%); opacity: 0.81" title="-0.156">old</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.55%); opacity: 0.81" title="0.184">winner</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.29%); opacity: 0.80" title="0.091">statewide</span><span style="opacity: 0.80"> competition </span><span style="background-color: hsl(120, 100.00%, 94.66%); opacity: 0.81" title="0.239">hold</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.71%); opacity: 0.83" title="0.609">fullerton</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.24%); opacity: ...

# %%
text, label = get_doc(text_label, 4, 'left')
print(label)
aareloaded_predictor.explain(text)
# Out:
# left
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=left
#
# </b>
#
#
#     (probability <b>0.998</b>, score <b>6.641</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.159
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.482
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 97.33%); opacity: 0.80" title="-0.103">walmart</span><span style="opacity: 0.80"> draw </span><span style="background-color: hsl(0, 100.00%, 94.03%); opacity: 0.81" title="-0.327">fire</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.50%); opacity: 0.81" title="-0.152">plan</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.51%); opacity: 0.81" title="0.368">phase</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.41%); opacity: 0.80" title="0.049">greeters</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.83%); opacity: 0.81" title="-0.266">welcome</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.80%); opacity: 0.80" title="-0.078">customer</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.35%); opacity: 0.80" title="-0.014">store</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.75%); opacity: 0.81" title="-0.137">retail</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.41%); opacity: 0.81" title="-0.158">giant</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.62%); opacity: 0.80" title="0.006">start</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.53%); opacity: 0.81" title="0.216">replace</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.99%); opacity: 0.81" title="0.255">greeters</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.39%); opacity: 0.82" title="0.551">roughly</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.31%); opacity: 0.82" title="0.384">1000</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.18%); opacity: 0.81" title="0.172">location</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.82%); opacity: 0.81" title="0.133">company</span><span style="opacity: 0.80"> customer </span><span style="background-color: hsl(0, 100.00%, 96.88%); opacity: 0.81" title="-0.129">accord</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.33%); opacity: 0.80" title="-0.103">walmart</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.44%); opacity: 0.80" title="0.011">spokesperson</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.97%); opacity: 0.81" title="0.256">position</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.28%); opacity: 0.80" title="-0.016">require</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.40%); opacity: 0.80" title="0.050">employee</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.52%); opacity: 0.80" title="-0.009">check</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.40%); opacity: 0.80" title="0.050">receipt</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.91%); opacity: 0.80" title="-0.001">help</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.36%); opacity: 0.80" title="-0.102">product</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.23%); opacity: 0.81" title="-0.311">return</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.64%); opacity: 0.80" title="0.039">generally</span><span style="opacity: 0.80"> </span><span style="background-color: h ...

# %% [markdown]
# # Center

# %%
text, label = get_doc(text_label, 0, 'center')
print(label)
aareloaded_predictor.explain(text)
# Out:
# center
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=center
#
# </b>
#
#
#     (probability <b>0.999</b>, score <b>12.272</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +13.077
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.805
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 85.86%); opacity: 0.85" title="1.527">washington</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="6.745">reuters</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 82.82%); opacity: 0.86" title="2.017">democrat</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.62%); opacity: 0.81" title="0.384">house</span><span style="opacity: 0.80"> representative </span><span style="background-color: hsl(120, 100.00%, 97.26%); opacity: 0.80" title="0.146">unveil</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.56%); opacity: 0.81" title="-0.292">ambitious</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.60%); opacity: 0.80" title="-0.121">proposal</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.70%); opacity: 0.80" title="0.114">tuesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.34%); opacity: 0.80" title="0.141">american</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.85%); opacity: 0.81" title="-0.179">government</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.49%); opacity: 0.81" title="0.298">medicare</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.28%); opacity: 0.82" title="0.528">health</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.35%); opacity: 0.81" title="0.311">insurance</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.14%); opacity: 0.81" title="0.332">program</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.76%); opacity: 0.80" title="-0.110">tap</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.94%); opacity: 0.80" title="0.038">public</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.17%); opacity: 0.80" title="0.026">frustration</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.21%); opacity: 0.80" title="-0.025">rise</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.63%); opacity: 0.81" title="0.197">cost</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.86%); opacity: 0.80" title="0.042">healthcare</span><span style="opacity: 0.80"> key </span><span style="background-color: hsl(0, 100.00%, 99.30%); opacity: 0.80" title="-0.021">party</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.69%); opacity: 0.81" title="0.191">seek</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.47%); opacity: 0.81" title="0.301">gain</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.93%); opacity: 0.80" title="0.038">control</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.66%); opacity: 0.80" title="-0.053">congress</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.69%); opacity: 0.81" title="0.192">white</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.53%); opacity: 0.80" title="0.126">house</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.85%); opacity: 0.80" title="0.002">bill</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.23%); opacity: 0.80" title="0.148">unveil</span><span style="opacity: 0.80"> </span><span style="bac ...

# %%
text, label = get_doc(text_label, 1, 'center')
print(label)
aareloaded_predictor.explain(text)
# Out:
# center
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=center
#
# </b>
#
#
#     (probability <b>0.998</b>, score <b>7.523</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.399
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.876
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 96.92%); opacity: 0.81" title="0.201">balakot</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.08%); opacity: 0.80" title="0.186">pakistan</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.12%); opacity: 0.85" title="2.085">delhi</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="7.803">reuters</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.85%); opacity: 0.85" title="1.769">india</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.30%); opacity: 0.82" title="-0.883">warplanes</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.72%); opacity: 0.81" title="0.554">kill</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.89%); opacity: 0.81" title="0.302">large</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.81%); opacity: 0.80" title="0.004">numb</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.62%); opacity: 0.81" title="0.229">fighter</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.99%); opacity: 0.80" title="-0.041">strike</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.71%); opacity: 0.80" title="-0.058">militant</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.98%); opacity: 0.80" title="-0.194">train</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.74%); opacity: 0.80" title="-0.056">camp</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.89%); opacity: 0.81" title="-0.203">inside</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.90%); opacity: 0.81" title="-0.411">pakistan</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.40%); opacity: 0.80" title="-0.019">tuesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.74%); opacity: 0.80" title="0.056">raise</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.27%); opacity: 0.80" title="-0.026">risk</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.42%); opacity: 0.80" title="0.077">conflict</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.39%); opacity: 0.80" title="-0.079">nuclear</span><span style="opacity: 0.80"> arm </span><span style="background-color: hsl(0, 100.00%, 96.63%); opacity: 0.81" title="-0.228">neighbour</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.14%); opacity: 0.80" title="0.180">pakistan</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.79%); opacity: 0.80" title="0.053">deny</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.86%); opacity: 0.80" title="0.048">casualty</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.95%); opacity: 0.80" title="0.001">pakistan</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.70%); opacity: 0.80" title="0.059">respond</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.85%); opacity: 0.81" title="-0.207">place</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.42%); opacity: 0.82" title="-0.592">choice</span><span style="opacity: 0.80"> military </span><span style="background-color: hsl(120 ...

# %%
text, label = get_doc(text_label, 2, 'center')
print(label)
aareloaded_predictor.explain(text)
# Out:
# center
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=center
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>12.635</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +13.373
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.737
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 84.81%); opacity: 0.85" title="1.823">washington</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="7.270">reuters</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.13%); opacity: 0.84" title="1.440">democratic</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.45%); opacity: 0.81" title="-0.433">lawmaker</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.79%); opacity: 0.81" title="-0.292">question</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.47%); opacity: 0.80" title="0.140">president</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.06%); opacity: 0.80" title="0.097">donald</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.36%); opacity: 0.80" title="0.076">trump</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.06%); opacity: 0.80" title="-0.097">aide</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.08%); opacity: 0.80" title="-0.173">michael</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.41%); opacity: 0.80" title="-0.073">cohen</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.83%); opacity: 0.80" title="-0.003">public</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.57%); opacity: 0.80" title="-0.133">hear</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.68%); opacity: 0.81" title="0.208">wednesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.30%); opacity: 0.80" title="0.155">trump</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.66%); opacity: 0.80" title="-0.126">lawyer</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.92%); opacity: 0.81" title="-0.186">mislead</span><span style="opacity: 0.80"> ethic </span><span style="background-color: hsl(0, 100.00%, 98.39%); opacity: 0.80" title="-0.074">illegal</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.41%); opacity: 0.80" title="-0.072">hush</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.56%); opacity: 0.80" title="-0.012">payment</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.64%); opacity: 0.80" title="-0.128">woman</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.68%); opacity: 0.81" title="0.302">2016</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.68%); opacity: 0.81" title="0.303">presidential</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.40%); opacity: 0.80" title="-0.073">campaign</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.67%); opacity: 0.80" title="0.008">accord</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.75%); opacity: 0.82" title="-0.897">memo</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.68%); opacity: 0.85" title="1.845">reuters</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.51%); opacity: 0.82" title="-0.663">trump</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.51%); opacity: 0.80" title="0.066">personal</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, ...

# %%
text, label = get_doc(text_label, 3, 'center')
print(label)
aareloaded_predictor.explain(text)
# Out:
# center
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=center
#
# </b>
#
#
#     (probability <b>0.992</b>, score <b>17.138</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +17.909
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.771
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 86.79%); opacity: 0.84" title="1.313">washington</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="6.393">reuters</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.17%); opacity: 0.82" title="0.738">state</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.42%); opacity: 0.80" title="0.127">department</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.15%); opacity: 0.80" title="-0.026">refuse</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.61%); opacity: 0.81" title="-0.188">37000</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.86%); opacity: 0.80" title="0.098">visa</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.12%); opacity: 0.80" title="-0.081">application</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.20%); opacity: 0.80" title="-0.076">2018</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.85%); opacity: 0.81" title="-0.251">trump</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.30%); opacity: 0.81" title="-0.213">administration</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.66%); opacity: 0.80" title="0.007">travel</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.66%); opacity: 0.80" title="0.007">ban</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.49%); opacity: 0.80" title="-0.123">1000</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.07%); opacity: 0.80" title="0.084">previous</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.07%); opacity: 0.80" title="0.084">ban</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.36%); opacity: 0.80" title="-0.132">fully</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.37%); opacity: 0.80" title="0.131">effect</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.01%); opacity: 0.81" title="0.238">accord</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.32%); opacity: 0.81" title="0.212">agency</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.73%); opacity: 0.80" title="0.106">datum</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.80%); opacity: 0.81" title="0.256">release</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.09%); opacity: 0.80" title="0.151">tuesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.11%); opacity: 0.82" title="0.519">file</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.65%); opacity: 0.81" title="0.269">photo</span><span style="opacity: 0.80"> international </span><span style="background-color: hsl(120, 100.00%, 95.89%); opacity: 0.81" title="0.247">traveler</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.28%); opacity: 0.80" title="0.020">reflect</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.84%); opacity: 0.81" title="0.170">close</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.13%); opacity: 0.81" title="0.315">door</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(1 ...

# %%
text, label = get_doc(text_label, 4, 'center')
print(label)
aareloaded_predictor.explain(text)
# Out:
# center
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=center
#
# </b>
#
#
#     (probability <b>0.999</b>, score <b>13.379</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +14.075
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.696
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 90.26%); opacity: 0.83" title="-0.832">hollywood</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.57%); opacity: 0.84" title="1.316">florida</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="6.260">reuters</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.21%); opacity: 0.84" title="1.367">month</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.72%); opacity: 0.80" title="-0.046">deadly</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.01%); opacity: 0.80" title="0.032">tailings</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.27%); opacity: 0.80" title="-0.021">dam</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.79%); opacity: 0.80" title="0.042">disaster</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.34%); opacity: 0.81" title="0.205">vale</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.51%); opacity: 0.81" title="-0.192">sa</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.23%); opacity: 0.81" title="-0.215">facility</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.53%); opacity: 0.80" title="-0.056">brazil</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.63%); opacity: 0.80" title="-0.008">freeport</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.70%); opacity: 0.81" title="0.177">mcmoran</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.65%); opacity: 0.81" title="0.452">inc</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.94%); opacity: 0.81" title="0.159">chief</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.62%); opacity: 0.81" title="-0.184">executive</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.01%); opacity: 0.81" title="-0.320">richard</span><span style="opacity: 0.80"> adkerson send </span><span style="background-color: hsl(0, 100.00%, 97.73%); opacity: 0.80" title="-0.104">memo</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.41%); opacity: 0.80" title="-0.015">29000</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.42%); opacity: 0.80" title="-0.062">employee</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.20%); opacity: 0.80" title="0.140">immediately</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.96%); opacity: 0.81" title="0.324">report</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.07%); opacity: 0.80" title="0.150">safety</span><span style="opacity: 0.80"> concern </span><span style="background-color: hsl(120, 100.00%, 98.79%); opacity: 0.80" title="0.042">score</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.00%); opacity: 0.80" title="0.155">dam</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.60%); opacity: 0.81" title="0.185">company</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.77%); opacity: 0.81" title="0.439">operate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.13%); opacity: 0.81" title="0.404">file</span><span style="opacity: 0.80"> </span><span style="background-color: hsl ...

# %% [markdown]
# # Right

# %%
text, label = get_doc(text_label, 0, 'right')
print(label)
aareloaded_predictor.explain(text)
# Out:
# right
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=right
#
# </b>
#
#
#     (probability <b>0.989</b>, score <b>4.542</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.352
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 94.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.809
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 96.72%); opacity: 0.81" title="0.155">late</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.73%); opacity: 0.82" title="-0.580">unite</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.97%); opacity: 0.81" title="0.138">methodist</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.80%); opacity: 0.81" title="0.220">church</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.02%); opacity: 0.81" title="-0.281">deliberation</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.31%); opacity: 0.80" title="-0.117">lgbt</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.50%); opacity: 0.82" title="0.603">inclusion</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="5.513">local</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 67.44%); opacity: 0.95" title="4.108">5</span><span style="opacity: 0.80">:</span><span style="background-color: hsl(0, 100.00%, 93.96%); opacity: 0.81" title="-0.370">30</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.06%); opacity: 0.81" title="0.201">pm</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.88%); opacity: 0.82" title="0.667">delegate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.37%); opacity: 0.81" title="-0.179">crucial</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.50%); opacity: 0.80" title="0.105">conference</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.07%); opacity: 0.80" title="-0.132">unite</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.97%); opacity: 0.81" title="0.138">methodist</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.27%); opacity: 0.80" title="0.062">church</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.26%); opacity: 0.80" title="0.018">america</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.93%); opacity: 0.80" title="0.031">2</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.72%); opacity: 0.80" title="-0.092">large</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.20%); opacity: 0.81" title="-0.191">protestant</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.07%); opacity: 0.80" title="0.131">denomination</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.54%); opacity: 0.81" title="0.167">reject</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.03%); opacity: 0.80" title="-0.075">ease</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.96%); opacity: 0.81" title="0.286">faith</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.46%); opacity: 0.81" title="0.246">ban</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.17%); opacity: 0.80" title="-0.022">sex</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.21%); opacity: 0.80" title="-0.123">marriage</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.31%); opacity: 0.80" title="-0.017">ordination</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.94%);  ...

# %%
text, label = get_doc(text_label, 1, 'right')
print(label)
aareloaded_predictor.explain(text)
# Out:
# right
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=right
#
# </b>
#
#
#     (probability <b>0.999</b>, score <b>13.430</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +13.687
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.258
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 93.09%); opacity: 0.82" title="0.425">presidential</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.24%); opacity: 0.82" title="0.502">candidate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.29%); opacity: 0.84" title="1.132">kamala</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.10%); opacity: 0.82" title="0.611">harris</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.56%); opacity: 0.81" title="-0.226">bold</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.56%); opacity: 0.81" title="-0.303">interview</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.71%); opacity: 0.81" title="-0.148">tuesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.34%); opacity: 0.80" title="0.109">decriminalization</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.32%); opacity: 0.82" title="0.494">sex</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.79%); opacity: 0.81" title="-0.142">work</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.07%); opacity: 0.81" title="0.263">label</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.47%); opacity: 0.82" title="0.481">president</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.97%); opacity: 0.81" title="0.197">trump</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.81%); opacity: 0.80" title="-0.035">racist</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.56%); opacity: 0.80" title="-0.045">talk</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.72%); opacity: 0.81" title="-0.371">consent</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.74%); opacity: 0.81" title="-0.145">adult</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.52%); opacity: 0.80" title="-0.098">yes</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.91%); opacity: 0.81" title="0.275">consider</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.69%); opacity: 0.81" title="0.373">criminalize</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.46%); opacity: 0.82" title="-0.393">consensual</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.58%); opacity: 0.81" title="-0.225">behavior</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.48%); opacity: 0.81" title="-0.232">long</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.65%); opacity: 0.80" title="0.006">harm</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.84%); opacity: 0.80" title="-0.033">senator</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.67%); opacity: 0.80" title="0.090">harris</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.26%); opacity: 0.81" title="0.177">calif</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.75%); opacity: 0.80" title="-0.037">root</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.48%); opacity: 0.81" title="-0.162">point</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00 ...

# %%
text, label = get_doc(text_label, 2, 'right')
print(label)
aareloaded_predictor.explain(text)
# Out:
# right
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=right
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>13.886</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +14.034
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.147
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 86.61%); opacity: 0.84" title="-0.659">2</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.53%); opacity: 0.81" title="-0.233">large</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.25%); opacity: 0.82" title="0.248">protestant</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.57%); opacity: 0.81" title="-0.231">denomination</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.63%); opacity: 0.80" title="0.056">country</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.71%); opacity: 0.83" title="-0.453">prospect</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.22%); opacity: 0.81" title="-0.199">mass</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.00%); opacity: 0.82" title="0.316">defection</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.15%); opacity: 0.82" title="0.365">act</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.41%); opacity: 0.80" title="0.008">defiance</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.81%); opacity: 0.82" title="0.271">delegate</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.09%); opacity: 0.80" title="0.041">conference</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.01%); opacity: 0.81" title="0.161">st</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.04%); opacity: 0.81" title="0.160">louis</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.45%); opacity: 0.81" title="0.099">vote</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.66%); opacity: 0.82" title="0.280">tuesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.70%); opacity: 0.82" title="0.333">strengthen</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.90%); opacity: 0.81" title="-0.122">unite</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.35%); opacity: 0.80" title="0.033">methodist</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.17%); opacity: 0.80" title="-0.012">church</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.16%); opacity: 0.81" title="0.111">ban</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.33%); opacity: 0.80" title="0.034">sex</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.48%); opacity: 0.81" title="0.140">marriage</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.31%); opacity: 0.81" title="0.194">ordination</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.73%); opacity: 0.83" title="-0.516">lgbtq</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.22%); opacity: 0.82" title="-0.303">clergy</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.11%); opacity: 0.86" title="-0.919">intense</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.63%); opacity: 0.83" title="-0.396">discussion</span><span style="opacity: 0.80"> general </span><span style="background-color: hsl(0, 100.00%, 96.26%); opacity: 0.81" title="-0.107">conference</span><span style="opacity: 0.80"> </span><span style="background-color:  ...

# %%
text, label = get_doc(text_label, 3, 'right')
print(label)
aareloaded_predictor.explain(text)
# Out:
# right
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=right
#
# </b>
#
#
#     (probability <b>0.979</b>, score <b>6.345</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.931
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 96.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.586
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 94.76%); opacity: 0.81" title="0.107">democrat</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.82%); opacity: 0.84" title="-0.358">tuesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.80%); opacity: 0.81" title="-0.106">push</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.36%); opacity: 0.81" title="0.090">unprecedented</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.94%); opacity: 0.82" title="-0.234">legislation</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.19%); opacity: 0.82" title="-0.225">house</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.09%); opacity: 0.87" title="0.722">block</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.957">president</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.16%); opacity: 0.87" title="0.668">trump</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.69%); opacity: 0.82" title="0.244">national</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.48%); opacity: 0.81" title="0.116">emergency</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.34%); opacity: 0.80" title="0.021">declaration</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.93%); opacity: 0.82" title="-0.235">steer</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.48%); opacity: 0.81" title="0.087">billion</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.86%); opacity: 0.81" title="0.077">extra</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.55%); opacity: 0.81" title="0.085">dollar</span><span style="opacity: 0.80"> southern </span><span style="background-color: hsl(0, 100.00%, 96.34%); opacity: 0.81" title="-0.064">border</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.59%); opacity: 0.81" title="-0.112">wall</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.28%); opacity: 0.80" title="-0.006">raise</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.21%); opacity: 0.80" title="0.044">prospect</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.92%); opacity: 0.81" title="-0.103">trump</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.30%); opacity: 0.80" title="0.006">veto</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 88.53%); opacity: 0.83" title="0.329">defeat</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.44%); opacity: 0.82" title="-0.216">effort</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.64%); opacity: 0.83" title="-0.284">vote</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.77%); opacity: 0.81" title="-0.079">245</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.08%); opacity: 0.82" title="0.160">182</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.55%); opacity: 0.84" title="0.412">democrat</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.38%); opacity: 0.82" title="0.150">vote</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 1 ...

# %%
text, label = get_doc(text_label, 4, 'right')
print(label)
aareloaded_predictor.explain(text)
# Out:
# right
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=right
#
# </b>
#
#
#     (probability <b>0.999</b>, score <b>8.341</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.527
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.186
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 92.64%); opacity: 0.82" title="0.394">florida</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.07%); opacity: 0.85" title="1.186">congressman</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.20%); opacity: 0.83" title="0.593">matt</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.65%); opacity: 0.81" title="0.186">gaetz</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.05%); opacity: 0.81" title="0.290">warn</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.81%); opacity: 0.81" title="0.239">ex</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.21%); opacity: 0.82" title="-0.351">trump</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.25%); opacity: 0.82" title="0.424">attorney</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.87%); opacity: 0.81" title="0.172">convict</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.57%); opacity: 0.81" title="-0.132">liar</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.01%); opacity: 0.80" title="0.022">michael</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.21%); opacity: 0.80" title="0.099">cohen</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.14%); opacity: 0.81" title="0.217">testify</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.92%); opacity: 0.81" title="-0.232">congress</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.80%); opacity: 0.81" title="-0.240">hey</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.77%); opacity: 0.80" title="-0.071">michaelcohen212</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.14%); opacity: 0.81" title="-0.157">wife</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.67%); opacity: 0.80" title="-0.076">father</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.72%); opacity: 0.81" title="0.245">law</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.99%); opacity: 0.81" title="0.227">girlfriend</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.94%); opacity: 0.80" title="0.064">gaetz</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.82%); opacity: 0.80" title="0.029">write</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.55%); opacity: 0.81" title="0.256">late</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.75%); opacity: 0.81" title="-0.180">tuesday</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.47%); opacity: 0.81" title="-0.197">maybe</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.49%); opacity: 0.80" title="0.041">tonight</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.08%); opacity: 0.81" title="-0.160">good</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.59%); opacity: 0.80" title="0.080">chat</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.14%); opacity: 0.80" title="-0.102">wonder</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.01%); opa ...
